# %% [markdown]
# ## This notebook will tell you why Henrik thinks naples is the best city to spend your holidays.

# %%
input("Name of traveller")
# Out:
# Name of travellerHenrik
# 'Henrik'

# %% [markdown]
# ![Foto%20am%2026.11.22%20um%2015.31.jpg](attachment:Foto%20am%2026.11.22%20um%2015.31.jpg)

# %% [markdown]
# ![Neapel.jpg](attachment:Neapel.jpg)

# %% [markdown]
# # top 3 to do in naples

# %% [markdown]
# - *eating Pizza*
# - *drinking Sprizz*
# - **more Pizza more sprizz**

# %% [markdown]
# # not to forget this one...

# %% [markdown]
# (https://www.youtube.com/watch?v=_ipl1mInKbY)

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/pBCBGWXiRGI"
# </iframe>

# %% [markdown]
# I have used the input() function, which will ask the user to type in the name of the travelling person.
