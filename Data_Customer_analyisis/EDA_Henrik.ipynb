# %%
#importing all the modules needeed for the EDA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#setting the dataframe

df = pd.read_csv('Data_Marketing_Customer_Analysis_Round3.csv')

# %%
#splitting the dataframe into numeerical and categorical

num_df = df.select_dtypes(include=[np.number])
num_df.head(10)
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0                     4809   48029                    61
# 1                     2228   92260                    64
# 2                    14947   22139                   100
# 3                    22332   49078                    97
# 4                     9025   23675                   117
# 5                     4745   50549                    61
# 6                     5035   37405                    63
# 7                     4956   87197                    63
# 8                     5989   66839                   154
# 9                    17114   70961                    85
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                        7                             52
# 1                        3                             26
# 2                       34                             31
# 3                       10                              3
# ...

# %%
cat_df = df.select_dtypes(exclude=[np.number])
cat_df.head(10)
# Out:
#         region response  coverage             education effective_to_date  \
# 0      central       no     basic               college           2/18/11
# 1  west region       no     basic               college           1/18/11
# 2         east       no     basic              bachelor           2/10/11
# 3   north west      yes  extended               college           1/11/11
# 4   north west       no   premium              bachelor           1/17/11
# 5  west region      yes     basic  high school or below           2/14/11
# 6  west region       no     basic                doctor           2/14/11
# 7  west region       no     basic  high school or below           2/24/11
# 8  west region      yes   premium               college           1/19/11
# 9   north west       no  extended                master            1/4/11
#
#   month employment_status gender location_code marital_status     policy_type  \
# ...

# %%
#distribution plots in one canvas via seaborn

fig, ax = plt.subplots(4, 2, figsize = (20,15)) 

# add an overall title for the figure
fig.suptitle('Distribution plots for the numerical variables', fontsize=18)

# create the plots, adding a title
sns.histplot(data=num_df, x='customer_lifetime_value', ax=ax[0,0], kde=True)
sns.histplot(data=num_df, x='income', ax=ax[0,1], kde=True)
sns.histplot(data=num_df, x='monthly_premium_auto', ax=ax[1,0], kde=True)
sns.histplot(data=num_df, x='months_since_last_claim', ax=ax[1,1], kde=True)
sns.histplot(data=num_df, x='months_since_policy_inception', ax=ax[2,0], kde=True)
sns.histplot(data=num_df, x='number_of_open_complaints', ax=ax[2,1], kde=True)
sns.histplot(data=num_df, x='number_of_policies', ax=ax[3,0], kde=True)
sns.histplot(data=num_df, x='total_claim_amount', ax=ax[3,1], kde=True)
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Count'>

# %%
#distribution plots in one canvas using matplotlib

num_df.hist(figsize = (20,15))
# Out:
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
#showing the correlations between the different numerical values

sns.pairplot(num_df)

# %%
#heatmap of the correlations


sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#plotting the total number of responses

sns.histplot(cat_df['response'])
#response_sales = df.groupby(['sales', ])
# Out:
# <AxesSubplot:xlabel='response', ylabel='Count'>

# %%
#plot of the responses by sales channel
sns.countplot(data = df, x= 'sales_channel', hue='response')
# Out:
# <AxesSubplot:xlabel='sales_channel', ylabel='count'>

# %%
#Show a plot of the response by the total claim amount.
sns.histplot(data= df, x='total_claim_amount', hue='response')
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Count'>

# %%
sns.catplot(data= df, x='response', y='total_claim_amount')

# %%
#Show a plot of the response by income.


sns.histplot(data=df, x='income', hue='response', multiple='stack')
# Out:
# <AxesSubplot:xlabel='income', ylabel='Count'>

# %%
sns.catplot(data=df, x='response', y='income')

# %%
#finding no.1
#possible identification of 'best-case-customers'
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
plt.title('Customer Lifetime Value by Monthly Premium', size='25', fontweight='bold')

sns.scatterplot(data=num_df, x='monthly_premium_auto', y='customer_lifetime_value', hue='total_claim_amount')
# Out:
# <AxesSubplot:title={'center':'Customer Lifetime Value by Monthly Premium'}, xlabel='monthly_premium_auto', ylabel='customer_lifetime_value'>

# %%
#finding no. 2
#would like to identify the two lines
#makes sense, the higher the monthly premium, the higher the total claim
sns.scatterplot(data=num_df, x='monthly_premium_auto', y='total_claim_amount')
# Out:
# <AxesSubplot:xlabel='monthly_premium_auto', ylabel='total_claim_amount'>

# %%
#as expected - the better the coverage the higher the total claim amount


sns.violinplot(data=df, x='coverage', y='total_claim_amount')
# Out:
# <AxesSubplot:xlabel='coverage', ylabel='total_claim_amount'>

# %%
#hypothesis no.3 - car is a status symbol, the higher the income, the higher the premium, because expensive cars have higher premiums
#finding no.3 - surprise, no relation between income and monthly premium

sns.scatterplot(data=df, x='income', y='monthly_premium_auto')
# Out:
# <AxesSubplot:xlabel='income', ylabel='monthly_premium_auto'>

# %%
#finding - would have thought that people in the city have more accidents, therefore a higher amount of total claim 
#explanation - people from the suburbs drive into the city and have accidents there
sns.boxplot(data=df, x='location_code', y='total_claim_amount')
# Out:
# <AxesSubplot:xlabel='location_code', ylabel='total_claim_amount'>

# %%
sns.boxplot(data=df, x='gender', y='total_claim_amount')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='total_claim_amount'>

# %%
sns.boxplot(data=df, x='policy', y='total_claim_amount')
# Out:
# <AxesSubplot:xlabel='policy', ylabel='total_claim_amount'>

# %%
sns.boxplot(data=df, x='education', y='total_claim_amount')
# Out:
# <AxesSubplot:xlabel='education', ylabel='total_claim_amount'>

# %%
#probably nothing

sns.countplot(data = df, x= 'education', hue='response')
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
sns.pairplot(data=df, vars=['monthly_premium_auto','customer_lifetime_value'], hue='region')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
# ...

# %%
df['education'].value_counts('response')
# Out:
# bachelor                0.300309
# college                 0.293853
# high school or below    0.287772
# master                  0.081673
# doctor                  0.036393
# Name: education, dtype: float64
