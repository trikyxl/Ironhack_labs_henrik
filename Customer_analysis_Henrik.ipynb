# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100


def lower_case_column_names(df):
    df.columns=[i.lower() for i in df.columns]
    return df

def clean_state_column(dataframe):
    dataframe.rename(columns={'st':'state'}, inplace=True)
    return dataframe

# %%
# !pwd
# Out:
# /Users/henrik/Desktop/GitHub/IH_DA_FT_JAN_2023_Henriks_Version/Class_Materials/Case_Studies/Customer_Analysis_Case_Study/Data

# %%
file1 = pd.read_csv('file1.csv')
file1 = lower_case_column_names(file1)
file1 = file1 = file1.sort_index(axis=1)
clean_state_column(file1)
# Out:
#      customer customer lifetime value             education gender   income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 4003      NaN                     NaN                   NaN    NaN      NaN
# 4004      NaN                     NaN                   NaN    NaN      NaN
# 4005      NaN                     NaN                   NaN    NaN      NaN
# 4006      NaN                     NaN                   NaN    NaN      NaN
# 4007      NaN                     NaN                   NaN    NaN      NaN
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 4003                   NaN                       NaN             NaN
# 4004                   NaN                       NaN             NaN
# 4005                   NaN                       NaN             NaN
# 4006                   NaN                       NaN             NaN
# 4007                   NaN                       NaN             NaN
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 4003         NaN                 NaN            NaN
# 4004         NaN                 NaN            NaN
# 4005         NaN                 NaN            NaN
# 4006         NaN                 NaN            NaN
# 4007         NaN                 NaN            NaN
#
# [4008 rows x 11 columns]

# %%
file2 = pd.read_csv('file2.csv')
file2 = lower_case_column_names(file2)
file2 = file2 = file2.sort_index(axis=1)
clean_state_column(file2)
# Out:
#     customer customer lifetime value education gender  income  \
# 0    GS98873              323912.47%  Bachelor      F   16061
# 1    CW49887              462680.11%    Master      F   79487
# 2    MY31220              899704.02%   College      F   54230
# 3    UH35128             2580706.30%   College      F   71210
# 4    WH52799              380812.21%   College      F   94903
# ..       ...                     ...       ...    ...     ...
# 991  HV85198              847141.75%    Master      M   63513
# 992  BS91566              543121.91%   College      F   58161
# 993  IL40123              568964.41%   College      F   83640
# 994  MY32149              368672.38%    Master      F       0
# 995  SA91515              399258.39%  Bachelor      M       0
#
#      monthly premium auto number of open complaints     policy type  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# 2                     112                    1/0/00   Personal Auto
# 3                     214                    1/1/00   Personal Auto
# 4                      94                    1/0/00  Corporate Auto
# ..                    ...                       ...             ...
# 991                    70                    1/0/00   Personal Auto
# 992                    68                    1/0/00  Corporate Auto
# 993                    70                    1/0/00  Corporate Auto
# 994                    96                    1/0/00   Personal Auto
# 995                   111                    1/0/00   Personal Auto
#
#           state  total claim amount  vehicle class
# 0       Arizona          633.600000  Four-Door Car
# 1    California          547.200000            SUV
# 2    California          537.600000   Two-Door Car
# 3        Oregon         1027.200000     Luxury Car
# 4       Arizona          451.200000   Two-Door Car
# ..          ...                 ...            ...
# 991     Arizona          185.667213  Four-Door Car
# 992     Arizona          140.747286  Four-Door Car
# 993      Nevada          471.050488   Two-Door Car
# 994  California           28.460568   Two-Door Car
# 995  California          700.349052            SUV
#
# [996 rows x 11 columns]

# %%
file3 = pd.read_csv('file3.csv')
file3 = lower_case_column_names(file3)
file3 = file3 = file3.sort_index(axis=1)
clean_state_column(file3)
# Out:
#      customer  customer lifetime value             education gender  income  \
# 0     SA25987              3479.137523  High School or Below      M       0
# 1     TB86706              2502.637401                Master      M       0
# 2     ZL73902              3265.156348              Bachelor      F   25820
# 3     KX23516              4455.843406  High School or Below      F       0
# 4     FN77294              7704.958480  High School or Below      M   30366
# ...       ...                      ...                   ...    ...     ...
# 7065  LA72316             23405.987980              Bachelor      M   71941
# 7066  PK87824              3096.511217               College      F   21604
# 7067  TD14365              8163.890428              Bachelor      M       0
# 7068  UP19263              7524.442436               College      M   21941
# 7069  Y167826              2611.836866               College      M       0
#
#       monthly premium auto  number of open complaints     policy type  \
# 0                      104                          0   Personal Auto
# 1                       66                          0   Personal Auto
# 2                       82                          0   Personal Auto
# 3                      121                          0   Personal Auto
# 4                      101                          2   Personal Auto
# ...                    ...                        ...             ...
# 7065                    73                          0   Personal Auto
# 7066                    79                          0  Corporate Auto
# 7067                    85                          3  Corporate Auto
# 7068                    96                          0   Personal Auto
# 7069                    77                          0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington          499.200000   Two-Door Car
# 1        Arizona            3.468912   Two-Door Car
# 2         Nevada          393.600000  Four-Door Car
# 3     California          699.615192            SUV
# 4     California          484.800000            SUV
# ...          ...                 ...            ...
# 7065  California          198.234764  Four-Door Car
# 7066  California          379.200000  Four-Door Car
# 7067  California          790.784983  Four-Door Car
# 7068  California          691.200000  Four-Door Car
# 7069  California          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
file1.columns == file2.columns
file2.columns == file3.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
df = pd.concat([file1,file2,file3], axis=0)
df
# Out:
#      customer customer lifetime value             education gender   income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 7065  LA72316             23405.98798              Bachelor      M  71941.0
# 7066  PK87824             3096.511217               College      F  21604.0
# 7067  TD14365             8163.890428              Bachelor      M      0.0
# 7068  UP19263             7524.442436               College      M  21941.0
# 7069  Y167826             2611.836866               College      M      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 7065                  73.0                         0   Personal Auto
# 7066                  79.0                         0  Corporate Auto
# 7067                  85.0                         3  Corporate Auto
# 7068                  96.0                         0   Personal Auto
# 7069                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 7065  California          198.234764  Four-Door Car
# 7066  California          379.200000  Four-Door Car
# 7067  California          790.784983  Four-Door Car
# 7068  California          691.200000  Four-Door Car
# 7069  California          369.600000   Two-Door Car
#
# [12074 rows x 11 columns]

# %%
df = df.drop_duplicates()
df = df.drop("customer", axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9135 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer lifetime value    9127 non-null   object
#  1   education                  9134 non-null   object
#  2   gender                     9012 non-null   object
#  3   income                     9134 non-null   float64
#  4   monthly premium auto       9134 non-null   float64
#  5   number of open complaints  9134 non-null   object
#  6   policy type                9134 non-null   object
#  7   state                      9134 non-null   object
#  8   total claim amount         9134 non-null   float64
#  9   vehicle class              9134 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 785.0+ KB

# %%
df['customer lifetime value'] = df['customer lifetime value'].str.replace('%','')
#df['customer lifetime value'] = df['customer lifetime value'].astype(int)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yc/wft790592j143k8gw6c_18z40000gn/T/ipykernel_12222/1434940970.py in <module>
#       1 df['customer lifetime value'] = df['customer lifetime value'].str.replace('%','')
# ----> 2 df['customer lifetime value'] = df['customer lifetime value'].astype(int)
#       3 df.head(10)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1152         # work around NumPy brokenness, #1987
#    1153         if np.issubdtype(dtype.type, np.integer):
# -> 1154             return lib.astype_intsafe(arr, dtype)
#    1155
#    1156         # if we have a datetime/timedelta array of objects
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
df["state"].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
def clean_state(x):
    if x in ['AZ', 'Arizona']:
        return 'Arizona'
    elif x in ['Cali', 'California']:
        return 'California'
    elif x in ['Washington', 'WA']:
        return 'Washington'
    else:
        pass

# %%
df['state'] = list(map(clean_state, df['state'])) 
df['state'].unique()
# Out:
# array(['Washington', 'Arizona', None, 'California'], dtype=object)

# %%
df["gender"].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
def clean_gender(x):
    if x in ['M', 'Male']:
        return 'M'
    elif x in ['F', 'Femal', 'female']:
        return 'F'
    else:
        return 'NaN'

# %%
df['gender'] = list(map(clean_gender, df['gender'])) 
df['gender'].unique()
# Out:
# array(['NaN', 'F', 'M'], dtype=object)

# %%
df['number of open complaints']
# Out:
# 0       1/0/00
# 1       1/0/00
# 2       1/0/00
# 3       1/0/00
# 4       1/0/00
#          ...
# 7065         0
# 7066         0
# 7067         3
# 7068         0
# 7069         0
# Name: number of open complaints, Length: 9135, dtype: object

# %%
def clean_gender(x):
    if x in ['M', 'Male']:
        return 'M'
    elif x in ['F', 'Femal', 'female']:
        return 'F'
    else:
        return 'NaN'

# %%
df['number of open complaints'] = df['number of open complaints'].str.replace('(.*)/0/(.*)','0', regex=True)
df['number of open complaints'] = df['number of open complaints'].str.replace('(.*)/1/(.*)','1', regex=True)
df['number of open complaints'] = df['number of open complaints'].str.replace('(.*)/2/(.*)','2', regex=True)
df['number of open complaints'] = df['number of open complaints'].str.replace('(.*)/3/(.*)','3', regex=True)
df['number of open complaints'] = df['number of open complaints'].str.replace('(.*)/4/(.*)','4', regex=True)
df['number of open complaints'] = df['number of open complaints'].str.replace('(.*)/5/(.*)','5', regex=True)
df['number of open complaints'].unique()
# Out:
# array(['0', '2', '1', '3', '5', '4', nan], dtype=object)
